# %%
import matplotlib
# %matplotlib inline
from main import Environment
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Setup the Environment
# #### Specify the problem
# - **cifar**: CIFAR-10 image classification.
# - **mnist**: MNIST handwritten digit image classification.
# - **fashion_mnist**: Fashion-MNIST image classification.
#
# All models have data_size "small" or "standard", referring to the dataset with 50k and 5k training examples, respectively.
#
# #### Select a model
# - **conv**: Convolutional neural network.
# - **mlp**: Multi-layer perceptron with non-linear activations.
#
# #### Choose a set of the following algorithms
# - **TR_uniform**: Second order Trust Region algorithm with spherical trust region shape.
# - **TR_adagrad**: Second order Trust Region algorithm with ellipsoidal trust region shape (the diagonal Adagrad preconditioning matrix determines the shape of the ellipsoid).
# - **TR_adagrad**: Second order Trust Region algorithm with ellipsoidal trust region shape (the diagonal Adagrad preconditioning matrix determines the shape of the ellipsoid).
# - **SGD**
# - **Adagrad**
# - **RMSprop**

# %%
problem = "cifar"
data_size = "small" # or "standard"
model = "mlp"
methods = ["TR_adagrad", "SGD", "TR_rms"]

env = Environment(methods, model, problem, data_size)

# %% [markdown]
# # Run the methods

# %%
# With 'changes' we can change individual parameters for specific methods
changes = {method: {"max_time": 200} for method in methods}

env.run_training(changes)
# Out:
# [i] Running fc-model on cifar-10 with TR_adagrad optimizer.
# [i] No CUDA-capable device found. Running the algorithms on CPU significantly slows down training.
#   1%|          | 198/20000 [00:09<15:40, 21.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-41800f75bae3> in <module>
#       2 changes = {method: {"max_time": 200} for method in methods}
#       3
# ----> 4 env.run_training(changes)
#
# ~/Downloads/ETR/main.py in run_training(self, changes)
#     120         df = None
#     121         for method_name, method_path in self.method_paths.items():
# --> 122             df_new = Trainer(self.env, method_path, changes=changes[method_name]).run()
#     123             df_new["method"] = method_name
#     124
#
# ~/Downloads/ETR/main.py in run(self, y)
#      49         if self.opt["method"] == "TR":
# ...

# %% [markdown]
# # Create Plots

# %%
env.plot("backprops")

# %%
env.plot("time")

# %%
env.plot("iteration")
